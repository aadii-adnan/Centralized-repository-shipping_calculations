# %% [markdown]
# <a href="https://colab.research.google.com/github/aadii-adnan/Centralized-repository-shipping_calculations/blob/main/Logistic_Regression_Binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('insurance_data.csv')
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['age']],df.bought_insurance, test_size=0.1)

# %%
x_train
# Out:
# 24    50
# 20    21
# 7     60
# 5     56
# 25    54
# 4     46
# 3     52
# 2     47
# 6     55
# 13    29
# 26    23
# 17    58
# 18    19
# 15    55
# 1     25
# 8     62
# 23    45
# 16    25
# 9     61
# 14    49
# 19    18
# 22    40
# 0     22
# 21    26
# Name: age, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9531/1899172436.py in <cell line: 0>()
# ----> 1 model.predict(y_test)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     372         """
#     373         xp, _ = get_namespace(X)
# --> 374         scores = self.decision_function(X)
#     375         if len(scores.shape) == 1:
#     376             indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     349         xp, _ = get_namespace(X)
#     350
# ...

# %%
x_test
# Out:
#    age
# 8   62
# 3   52
# 6   55

# %%
model.predict([[33]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
model.predict_proba(x_test)
# Out:
# array([[5.87574355e-05, 9.99941243e-01],
#        [1.51127505e-03, 9.98488725e-01],
#        [5.70793192e-04, 9.99429207e-01]])

# %%
model.score(x_train,y_train)
# Out:
# 0.9583333333333334

# %%
model.score(x_test,y_test)
# Out:
# 0.3333333333333333
