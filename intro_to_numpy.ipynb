# %% [markdown]
# <a href="https://colab.research.google.com/github/aadii-adnan/Centralized-repository-shipping_calculations/blob/main/intro_to_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a2 = np.array([[1,2,3],[11,22,33]])

# %%
import pandas as pd

# %%
df = pd.DataFrame(a2)
df
# Out:
#     0   1   2
# 0   1   2   3
# 1  11  22  33

# %%
a2
# Out:
# array([[ 1,  2,  3],
#        [11, 22, 33]])

# %%
ones = np.ones((2,3))
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
range_array = np.arange(0,10,2)
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
random_array = np.random.randint(0,10 , size=(3,5))
random_array
# Out:
# array([[7, 8, 1, 5, 9],
#        [8, 9, 4, 3, 0],
#        [3, 5, 0, 2, 3]])

# %%
random_array_2 = np.random.random((5,3))
random_array_2
# Out:
# array([[0.79915856, 0.46147936, 0.78052918],
#        [0.11827443, 0.63992102, 0.14335329],
#        [0.94466892, 0.52184832, 0.41466194],
#        [0.26455561, 0.77423369, 0.45615033],
#        [0.56843395, 0.0187898 , 0.6176355 ]])

# %%
a3 = np.random.rand(3)
a3
# Out:
# array([0.61209572, 0.616934  , 0.94374808])

# %%
np.random.seed(0)
a4= np.random.random((5,3))
a4
# Out:
# array([[0.5488135 , 0.71518937, 0.60276338],
#        [0.54488318, 0.4236548 , 0.64589411],
#        [0.43758721, 0.891773  , 0.96366276],
#        [0.38344152, 0.79172504, 0.52889492],
#        [0.56804456, 0.92559664, 0.07103606]])

# %%
np.unique(a4)
# Out:
# array([0.07103606, 0.38344152, 0.4236548 , 0.43758721, 0.52889492,
#        0.54488318, 0.5488135 , 0.56804456, 0.60276338, 0.64589411,
#        0.71518937, 0.79172504, 0.891773  , 0.92559664, 0.96366276])

# %%
a4[1]
# Out:
# array([0.54488318, 0.4236548 , 0.64589411])

# %%
a4[:2,:2]
# Out:
# array([[0.5488135 , 0.71518937],
#        [0.54488318, 0.4236548 ]])

# %%
a4= np.random.randint(10,size=(2,3,4,5))

# %%
a4.shape,a4.ndim
# Out:
# ((2, 3, 4, 5), 4)

# %%
a4
# Out:
# array([[[[9, 4, 3, 0, 3],
#          [5, 0, 2, 3, 8],
#          [1, 3, 3, 3, 7],
#          [0, 1, 9, 9, 0]],
#
#         [[4, 7, 3, 2, 7],
#          [2, 0, 0, 4, 5],
#          [5, 6, 8, 4, 1],
#          [4, 9, 8, 1, 1]],
#
#         [[7, 9, 9, 3, 6],
#          [7, 2, 0, 3, 5],
#          [9, 4, 4, 6, 4],
#          [4, 3, 4, 4, 8]]],
#
#
#        [[[4, 3, 7, 5, 5],
#          [0, 1, 5, 9, 3],
#          [0, 5, 0, 1, 2],
#          [4, 2, 0, 3, 2]],
#
#         [[0, 7, 5, 9, 0],
#          [2, 7, 2, 9, 2],
#          [3, 3, 2, 3, 4],
#          [1, 2, 9, 1, 4]],
#
#         [[6, 8, 2, 3, 0],
#          [0, 6, 0, 6, 3],
#          [3, 8, 8, 8, 2],
#          [3, 2, 0, 8, 8]]]])

# %%
a4[:,:,:,:4]
# Out:
# array([[[[9, 4, 3, 0],
#          [5, 0, 2, 3],
#          [1, 3, 3, 3],
#          [0, 1, 9, 9]],
#
#         [[4, 7, 3, 2],
#          [2, 0, 0, 4],
#          [5, 6, 8, 4],
#          [4, 9, 8, 1]],
#
#         [[7, 9, 9, 3],
#          [7, 2, 0, 3],
#          [9, 4, 4, 6],
#          [4, 3, 4, 4]]],
#
#
#        [[[4, 3, 7, 5],
#          [0, 1, 5, 9],
#          [0, 5, 0, 1],
#          [4, 2, 0, 3]],
#
#         [[0, 7, 5, 9],
#          [2, 7, 2, 9],
#          [3, 3, 2, 3],
#          [1, 2, 9, 1]],
#
#         [[6, 8, 2, 3],
#          [0, 6, 0, 6],
#          [3, 8, 8, 8],
#          [3, 2, 0, 8]]]])

# %%
a5=np.random.random(size=(2,3,4,5,5))
a5
# Out:
# array([[[[[0.57615733, 0.59204193, 0.57225191, 0.22308163, 0.95274901],
#           [0.44712538, 0.84640867, 0.69947928, 0.29743695, 0.81379782],
#           [0.39650574, 0.8811032 , 0.58127287, 0.88173536, 0.69253159],
#           [0.72525428, 0.50132438, 0.95608363, 0.6439902 , 0.42385505],
#           [0.60639321, 0.0191932 , 0.30157482, 0.66017354, 0.29007761]],
#
#          [[0.61801543, 0.4287687 , 0.13547406, 0.29828233, 0.56996491],
#           [0.59087276, 0.57432525, 0.65320082, 0.65210327, 0.43141844],
#           [0.8965466 , 0.36756187, 0.43586493, 0.89192336, 0.80619399],
#           [0.70388858, 0.10022689, 0.91948261, 0.7142413 , 0.99884701],
#           [0.1494483 , 0.86812606, 0.16249293, 0.61555956, 0.12381998]],
#
#          [[0.84800823, 0.80731896, 0.56910074, 0.4071833 , 0.069167  ],
#           [0.69742877, 0.45354268, 0.7220556 , 0.86638233, 0.97552151],
#           [0.85580334, 0.01171408, 0.35997806, 0.72999056, 0.17162968],
# ...

# %%
a2 + ones
# Out:
# array([[ 2.,  3.,  4.],
#        [12., 23., 34.]])

# %%
a1 = np.array([1,2,3])

# %%
a1 + ones
# Out:
# array([[2., 3., 4.],
#        [2., 3., 4.]])

# %%
a1
# Out:
# array([1, 2, 3])

# %%
a1 + ones
# Out:
# array([[2., 3., 4.],
#        [2., 3., 4.]])

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
ones = np.ones(3)

# %%
ones
# Out:
# array([1., 1., 1.])

# %%
a1 + ones
# Out:
# array([2., 3., 4.])

# %%
a1*a2
# Out:
# array([[ 1,  4,  9],
#        [11, 44, 99]])

# %%
listy_list = [1,2,3]

# %%
sum(listy_list)
# Out:
# 6

# %%
massive_array=np.random.random(10000)
massive_array.size
# Out:
# 10000

# %%
np.random.seed(0)
sales_amount = np.random.randint (20, size= (5,3))

# %%
weakly_sales = pd.DataFrame(sales_amount, index=["Mon", "Tues", "Wed", "Thurs","Fri"], columns=["Almond Butter", "Peanut Butter", "Cashew Butter"])
weakly_sales
# Out:
#        Almond Butter  Peanut Butter  Cashew Butter
# Mon               12             15              0
# Tues               3              3              7
# Wed                9             19             18
# Thurs              4              6             12
# Fri                1              6              7

# %%
prices = np.array([10,8,12])
prices
# Out:
# array([10,  8, 12])

# %%
butter_prices = pd.DataFrame(prices.reshape (1,3), index=["Price"], columns=["Almond Butter", "Peanut Butter", "Cashew Butter"])
butter_prices
# Out:
#        Almond Butter  Peanut Butter  Cashew Butter
# Price             10              8             12

# %%
prices
# Out:
# array([10,  8, 12])

# %%
total_sales = prices.dot(sales_amount.T)
total_sales
# Out:
# array([240, 138, 458, 232, 142])

# %%
daily_sales = butter_prices.dot(weakly_sales.T)
daily_sales
# Out:
#        Mon  Tues  Wed  Thurs  Fri
# Price  240   138  458    232  142

# %%
weakly_sales ["Total $"] = daily_sales.T
weakly_sales
# Out:
#        Almond Butter  Peanut Butter  Cashew Butter  Total $
# Mon               12             15              0      240
# Tues               3              3              7      138
# Wed                9             19             18      458
# Thurs              4              6             12      232
# Fri                1              6              7      142

# %%
random_array
# Out:
# array([[7, 8, 1, 5, 9],
#        [8, 9, 4, 3, 0],
#        [3, 5, 0, 2, 3]])

# %%
np.sort(random_array)
# Out:
# array([[1, 5, 7, 8, 9],
#        [0, 3, 4, 8, 9],
#        [0, 2, 3, 3, 5]])

# %%
np.argsort(random_array)
# Out:
# array([[2, 3, 0, 1, 4],
#        [4, 3, 2, 0, 1],
#        [2, 3, 0, 4, 1]])

# %%
<img src="/content/panda.jpeg"/>
# Out:
#   File "/tmp/ipykernel_3038/547368393.py", line 1
#     <img src="/content/panda.jpeg"/>
#     ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "/tmp/ipykernel_3038/1314718008.py", line 1
#     <img src="/content/panda.jpeg" width="300">
#     ^
# SyntaxError: invalid syntax

# %%
from IPython.display import Image
Image('/content/panda.jpeg')

# %%
from matplotlib.image import imread
panda = imread('/content/panda.jpeg')
panda
# Out:
# array([[[ 89, 137,  51],
#         [ 75, 124,  33],
#         [ 84, 134,  39],
#         ...,
#         [ 54,  81,  48],
#         [ 55,  80,  48],
#         [ 55,  80,  48]],
#
#        [[ 97, 143,  55],
#         [ 93, 139,  49],
#         [ 95, 142,  46],
#         ...,
#         [ 53,  80,  47],
#         [ 54,  79,  47],
#         [ 54,  79,  47]],
#
#        [[ 68, 113,  22],
#         [ 99, 144,  51],
#         [ 91, 137,  39],
#         ...,
#         [ 52,  79,  46],
#         [ 53,  78,  46],
#         [ 53,  78,  46]],
#
#        ...,
#
#        [[ 17,  21,   6],
#         [ 16,  20,   5],
#         [ 15,  19,   4],
#         ...,
#         [ 18,  43,  14],
#         [ 18,  43,  14],
#         [ 18,  43,  14]],
#
#        [[ 17,  21,   6],
#         [ 16,  20,   5],
#         [ 15,  19,   4],
#         ...,
#         [ 15,  40,  11],
#         [ 15,  40,  11],
#         [ 15,  40,  11]],
#
#        [[ 16,  20,   5],
#         [ 16,  20,   5],
#         [ 15,  19,   4],
# ...

# %%
panda.size , panda.shape, panda.ndim
# Out:
# (151200, (168, 300, 3), 3)
